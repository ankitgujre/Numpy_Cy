# %%
import numpy as np
n=np.array([10,20,30,40,50,60,70,80])

# %%
print(n[:4])
# Out:
# [10 20 30 40]

# %%
print(n[4:2])
# Out:
# []

# %%
print(n[4:])
# Out:
# [50 60 70 80]

# %%
print(n[:4:3])
# Out:
# [10 40]

# %%
print(n[-1:])
# Out:
# [80]

# %%
print(n[-4:])
# Out:
# [50 60 70 80]

# %%
print(n[-6:])
# Out:
# [30 40 50 60 70 80]

# %%
print(n[-3:-1])
# Out:
# [60 70]

# %%
print(n[-8:])
# Out:
# [10 20 30 40 50 60 70 80]

# %%
print(n[:6:2])
# Out:
# [10 30 50]

# %%
print(n[:-6:-2])
# Out:
# [80 60 40]

# %%
print(n[:-3:2])
# Out:
# [10 30 50]

# %%
print(n[:-5:-1])
# Out:
# [80 70 60 50]

# %%
print(n[:-5:-3])
# Out:
# [80 50]

# %%
print(n[:-5:3])
# Out:
# [10]
